# %%
# import tkinter as tk
# win=tk.Tk()
# win.mainloop()
# ###mehema thami main loop eka hadanne

# %%
# import tkinter as tk
# width=500
# height=500
# win=tk.Tk()
# canvas=tk.Canvas(win,width=width,height=height,bg='white')
# canvas.grid(row=0,column=0)
# win.mainloop()
##canvas eka dana widiya

# %%
# import tkinter as tk
# width=500
# height=500
# font_btn='Helvetica 20 bold'
# win=tk.Tk()
# canvas=tk.Canvas(win,width=width,height=height,bg='white')
# canvas.grid(row=0,column=0,columnspan=4)

# button_save=tk.Button(win,text='save',bg='green',fg='white',font=font_btn)
# button_save.grid(row=1,column=0)
# button_predict=tk.Button(win,text='predict',bg='blue',fg='white',font=font_btn)
# button_predict.grid(row=1,column=1)
# button_clear=tk.Button(win,text='clear',bg='red',fg='white',font=font_btn)
# button_clear.grid(row=1,column=2)
# button_exit=tk.Button(win,text='exit',bg='pink',fg='white',font=font_btn)
# button_exit.grid(row=1,column=3)
# label_status=tk.Label(win,text='predicted character:NONE',bg='white',font=font_btn)
# label_status.grid(row=2,column=0,columnspan=4)

# win.mainloop()

# %%
# import tkinter as tk
# width=500
# height=500
# font_btn='Helvetica 20 bold'
# win=tk.Tk()

# def event_function(event):
#     print('here!')
# canvas=tk.Canvas(win,width=width,height=height,bg='white')
# canvas.grid(row=0,column=0,columnspan=4)

# button_save=tk.Button(win,text='save',bg='green',fg='white',font=font_btn)
# button_save.grid(row=1,column=0)
# button_predict=tk.Button(win,text='predict',bg='blue',fg='white',font=font_btn)
# button_predict.grid(row=1,column=1)
# button_clear=tk.Button(win,text='clear',bg='red',fg='white',font=font_btn)
# button_clear.grid(row=1,column=2)
# button_exit=tk.Button(win,text='exit',bg='pink',fg='white',font=font_btn)
# button_exit.grid(row=1,column=3)
# label_status=tk.Label(win,text='predicted character:NONE',bg='white',font=font_btn)
# label_status.grid(row=2,column=0,columnspan=4)

# canvas.bind('<B1-Motion>',event_function)

# win.mainloop()
##mous  event funtion eka thami use kall thiyenne
# Out:
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# ...

# %%
# !pip install pillow

# %%
# import tkinter as tk
# width=500
# height=500
# font_btn='Helvetica 20 bold'
# win=tk.Tk()

# def event_function(event):
#     x=event.x
#     y=event.y

#     x1=x-30
#     x2=x+30

#     y1=y-30
#     y2=y+30

#     canvas.create_oval(x1, y1, x2, y2, fill='black')
    
  
# canvas=tk.Canvas(win,width=width,height=height,bg='white')
# canvas.grid(row=0,column=0,columnspan=4)

# button_save=tk.Button(win,text='save',bg='green',fg='white',font=font_btn)
# button_save.grid(row=1,column=0)
# button_predict=tk.Button(win,text='predict',bg='blue',fg='white',font=font_btn)
# button_predict.grid(row=1,column=1)
# button_clear=tk.Button(win,text='clear',bg='red',fg='white',font=font_btn)
# button_clear.grid(row=1,column=2)
# button_exit=tk.Button(win,text='exit',bg='pink',fg='white',font=font_btn)
# button_exit.grid(row=1,column=3)
# label_status=tk.Label(win,text='predicted character:NONE',bg='white',font=font_btn)
# label_status.grid(row=2,column=0,columnspan=4)

# canvas.bind('<B1-Motion>',event_function)

# win.mainloop()
# Out:
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# here!
# ...

# %%
# import tkinter as tk
# from PIL import ImageTk,Image,ImageDraw
# width=500
# height=500
# font_btn='Helvetica 20 bold'
# win=tk.Tk()

# def event_function(event):
#     x=event.x
#     y=event.y

#     x1=x-30
#     x2=x+30

#     y1=y-30
#     y2=y+30

#     canvas.create_oval(x1, y1, x2, y2, fill='black')
#     img_draw.ellipse((x1,y1,x2,y2),fill='black')
    
  
# canvas=tk.Canvas(win,width=width,height=height,bg='white')
# canvas.grid(row=0,column=0,columnspan=4)

# button_save=tk.Button(win,text='save',bg='green',fg='white',font=font_btn)
# button_save.grid(row=1,column=0)
# button_predict=tk.Button(win,text='predict',bg='blue',fg='white',font=font_btn)
# button_predict.grid(row=1,column=1)
# button_clear=tk.Button(win,text='clear',bg='red',fg='white',font=font_btn)
# button_clear.grid(row=1,column=2)
# button_exit=tk.Button(win,text='exit',bg='pink',fg='white',font=font_btn)
# button_exit.grid(row=1,column=3)
# label_status=tk.Label(win,text='predicted character:NONE',bg='white',font=font_btn)
# label_status.grid(row=2,column=0,columnspan=4)

# canvas.bind('<B1-Motion>',event_function)
# img=Image.new('RGB',(width,height),(255,255,255))
# img_draw=ImageDraw.Draw(img)

# win.mainloop()

# %%
# import tkinter as tk
# from PIL import ImageTk,Image,ImageDraw
# import numpy as np
# import cv2  
# width=500
# height=500
# font_btn='Helvetica 20 bold'
# win=tk.Tk()

# def event_function(event):
#     x=event.x
#     y=event.y

#     x1=x-30
#     x2=x+30

#     y1=y-30
#     y2=y+30

#     canvas.create_oval(x1, y1, x2, y2, fill='black')
#     img_draw.ellipse((x1,y1,x2,y2),fill='black')

# def save():
#     img_array=np.array(img)
#     cv2.imwrite('data/save.png',img_array)
    
  
# canvas=tk.Canvas(win,width=width,height=height,bg='white')
# canvas.grid(row=0,column=0,columnspan=4)

# button_save=tk.Button(win,text='save',bg='green',fg='white',font=font_btn,command=save)
# button_save.grid(row=1,column=0)
# button_predict=tk.Button(win,text='predict',bg='blue',fg='white',font=font_btn)
# button_predict.grid(row=1,column=1)
# button_clear=tk.Button(win,text='clear',bg='red',fg='white',font=font_btn)
# button_clear.grid(row=1,column=2)
# button_exit=tk.Button(win,text='exit',bg='pink',fg='white',font=font_btn)
# button_exit.grid(row=1,column=3)
# label_status=tk.Label(win,text='predicted character:NONE',bg='white',font=font_btn)
# label_status.grid(row=2,column=0,columnspan=4)

# canvas.bind('<B1-Motion>',event_function)
# img=Image.new('RGB',(width,height),(255,255,255))
# img_draw=ImageDraw.Draw(img)

# win.mainloop()

# %%
import tkinter as tk
from PIL import ImageTk,Image,ImageDraw
import numpy as np
import cv2  
import os
import joblib

model=joblib.load('mysinhala-character-knn.sav')
lavel_dict={0:'අ',1:'එ',2:'ඉ',3:'උ'}


width=500
height=500
count=0
font_btn='Helvetica 20 bold'
win=tk.Tk()

def event_function(event):
    x=event.x
    y=event.y

    x1=x-30
    x2=x+30

    y1=y-30
    y2=y+30

    canvas.create_oval(x1, y1, x2, y2, fill='black')
    img_draw.ellipse((x1,y1,x2,y2),fill='black')

def save():
    global count
    img_array=np.array(img)
    path=os.path.join('data',str(count)+'.jpg')
    cv2.imwrite(path,img_array)
    count=count+1


def clear():
    global img,img_draw
    canvas.delete('all')
    img=Image.new('RGB',(width,height),(255,255,255))
    img_draw=ImageDraw.Draw(img)
    label_status.config(text='predicted character:NONE')

def predict():
    img_array=np.array(img)
    img_array=cv2.cvtColor(img_array,cv2.COLOR_BGR2GRAY)
    img_array=cv2.resize(img_array,(8,8))
    img_array=np.reshape(img_array,(1,64))

    result=model.predict(img_array)[0] ##meka multidimenthional ena nisa api 0 dala eke palaweni element eka gnnawa 
    print(lavel_dict[result])
    label=lavel_dict[result]
    label_status.config(text='predicted character:'+label)
    


canvas=tk.Canvas(win,width=width,height=height,bg='white')
canvas.grid(row=0,column=0,columnspan=4)

button_save=tk.Button(win,text='save',bg='green',fg='white',font=font_btn,command=save)
button_save.grid(row=1,column=0)
button_predict=tk.Button(win,text='predict',bg='blue',fg='white',font=font_btn,command=predict)
button_predict.grid(row=1,column=1)
button_clear=tk.Button(win,text='clear',bg='red',fg='white',font=font_btn,command=clear)
button_clear.grid(row=1,column=2)
button_exit=tk.Button(win,text='exit',bg='pink',fg='white',font=font_btn,command=win.destroy)
button_exit.grid(row=1,column=3)
label_status=tk.Label(win,text='predicted character:NONE',bg='white',font=font_btn)
label_status.grid(row=2,column=0,columnspan=4)

canvas.bind('<B1-Motion>',event_function)
img=Image.new('RGB',(width,height),(255,255,255))
img_draw=ImageDraw.Draw(img)

win.mainloop()
# Out:
# එ
# අ
# අ
# ඉ
# උ
# එ
# අ
# අ
# අ
